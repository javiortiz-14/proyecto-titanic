# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (2.5.1)
# Requirement already satisfied: matplotlib in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (3.11.1)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/83/a4/c8e67227c680e2259c8864ae72ff48b06e16a6f51253a22167aa02a8aa4e/scikit_learn-1.9.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.10.0 from https://files.pythonhosted.org/packages/2b/54/9a9edb45345bd6744da5ddfb6628e5d5185920494c6a67ec45b6381004cb/scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.4.0 from https://files.pythonhosted.org/packages/7b/91/984aca2ec129e2757d1e4e3c81c3fcda9d0f85b74670a094cc443d9ee949/joblib-1.5.3-py3-none-any.whl.metadata
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Obtaining dependency information for narwhals>=2.0.1 from https://files.pythonhosted.org/packages/7e/85/a5bfaebfd305ac18b57b0854d74e37e586809061a91fda62f0bd50c8518e/narwhals-2.24.0-py3-none-any.whl.metadata
#   Using cached narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.5.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\javier\desktop\proyectos_\git_titanic\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached scikit_learn-1.9.0-cp312-cp312-win_amd64.whl (8.2 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.24.0-py3-none-any.whl (461 kB)
# Using cached scipy-1.18.0-cp312-cp312-win_amd64.whl (36.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
# Successfully installed joblib-1.5.3 narwhals-2.24.0 scikit-learn-1.9.0 scipy-1.18.0 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Cargar el archivo del Titanic que tienes en la carpeta
df = pd.read_csv('train.csv')

# Mostrar las primeras 5 filas
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Survived', data=df)
plt.title('Supervivientes (0=No, 1=Sí)')
plt.show()

print(df['Survived'].value_counts(normalize=True))
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
sns.barplot(x = "Sex", y = "Survived",data= df)
plt.title("Tasa de supervivencia por genero")
plt.show()

# %%
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Tasa de supervivencia por clase')
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', bins=30)
plt.title('Distribución de edad por supervivencia')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm")
plt.title("Correlación entre variables")
plt.show()

# %%
print(df.isnull().sum())
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'FamilySize']
X = df[features]
y = df['Survived']
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
